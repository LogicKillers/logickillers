# %%
# !pip install flytekit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flytekit
#   Downloading flytekit-1.3.1-py3-none-any.whl (412 kB)
# Requirement already satisfied: pyopenssl in c:\programdata\anaconda3\lib\site-packages (from flytekit) (21.0.0)
# Collecting diskcache>=5.2.1
#   Downloading diskcache-5.4.0-py3-none-any.whl (44 kB)
# Requirement already satisfied: deprecated<2.0,>=1.0 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from flytekit) (1.2.13)
# Requirement already satisfied: sortedcontainers<3.0.0,>=1.5.9 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (2.4.0)
# Collecting dataclasses-json>=0.5.2
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (2.8.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.22 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from flytekit) (1.24.3)
# Collecting natsort>=7.0.1
#   Downloading natsort-8.2.0-py3-none-any.whl (37 kB)
# Collecting googleapis-common-protos>=1.57
#   Downloading googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# Collecting docker-image-py>=0.1.10
#   Downloading docker-image-py-0.1.12.tar.gz (8.2 kB)
# Requirement already satisfied: numpy<1.24.0 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (1.21.5)
# Collecting cloudpickle>=2.0.0
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting statsd<4.0.0,>=3.0.0
#   Downloading statsd-3.3.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from flytekit) (2021.3)
# Collecting docstring-parser>=0.9.0
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Collecting responses>=0.10.7
#   Downloading responses-0.22.0-py3-none-any.whl (51 kB)
# Requirement already satisfied: importlib-metadata in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from flytekit) (4.13.0)
# Requirement already satisfied: wheel<1.0.0,>=0.30.0 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (0.37.1)
# Collecting pyarrow<11.0.0,>=4.0.0
#   Downloading pyarrow-10.0.1-cp39-cp39-win_amd64.whl (20.3 MB)
# Requirement already satisfied: croniter<4.0.0,>=0.3.20 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from flytekit) (1.3.8)
# Requirement already satisfied: gitpython in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from flytekit) (3.1.28)
# Collecting grpcio-status<2.0,>=1.50.0
#   Downloading grpcio_status-1.51.1-py3-none-any.whl (5.1 kB)
# Collecting retry==0.9.2
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.4 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (2.27.1)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from flytekit) (6.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from flytekit) (4.1.1)
# Requirement already satisfied: click<9.0,>=6.6 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from flytekit) (7.0)
# Collecting grpcio<2.0,>=1.50.0
#   Downloading grpcio-1.51.1-cp39-cp39-win_amd64.whl (3.7 MB)
# Collecting flyteidl<1.4.0,>=1.3.0
#   Downloading flyteidl-1.3.4-py3-none-any.whl (180 kB)
# Requirement already satisfied: keyring>=18.0.1 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (23.4.0)
# Collecting docker<7.0.0,>=5.0.3
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
# Collecting pytimeparse<2.0.0,>=1.1.8
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: cookiecutter>=1.7.3 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (1.7.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from flytekit) (1.12.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from flytekit) (1.1.0)
# Collecting marshmallow-jsonschema>=0.12.0
#   Downloading marshmallow_jsonschema-0.13.0-py3-none-any.whl (11 kB)
# Collecting python-json-logger>=2.0.0
#   Downloading python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\programdata\anaconda3\lib\site-packages (from retry==0.9.2->flytekit) (1.11.0)
# Requirement already satisfied: decorator>=3.4.2 in c:\programdata\anaconda3\lib\site-packages (from retry==0.9.2->flytekit) (5.1.1)
# Requirement already satisfied: poyo>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.7.3->flytekit) (0.5.0)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.7.3->flytekit) (5.0.2)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.7.3->flytekit) (0.2.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from cookiecutter>=1.7.3->flytekit) (2.11.3)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.7.3->flytekit) (0.4.4)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.7.3->flytekit) (1.16.0)
# Requirement already satisfied: chardet>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from binaryornot>=0.4.4->cookiecutter>=1.7.3->flytekit) (4.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from dataclasses-json>=0.5.2->flytekit) (3.19.0)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from dataclasses-json>=0.5.2->flytekit) (1.5.1)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from docker<7.0.0,>=5.0.3->flytekit) (0.58.0)
# Collecting urllib3<2.0.0,>=1.22
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: packaging>=14.0 in c:\programdata\anaconda3\lib\site-packages (from docker<7.0.0,>=5.0.3->flytekit) (21.3)
# Collecting pywin32>=304
#   Downloading pywin32-305-cp39-cp39-win_amd64.whl (12.2 MB)
# Requirement already satisfied: regex>=2019.4.14 in c:\programdata\anaconda3\lib\site-packages (from docker-image-py>=0.1.10->flytekit) (2022.3.15)
# Collecting protobuf<5.0.0,>=4.21.1
#   Downloading protobuf-4.21.12-cp39-cp39-win_amd64.whl (527 kB)
# Collecting protoc-gen-swagger
#   Downloading protoc_gen_swagger-0.1.0-py2.py3-none-any.whl (9.4 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=1.7.3->flytekit) (2.1.2)
# Requirement already satisfied: arrow in c:\programdata\anaconda3\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter>=1.7.3->flytekit) (1.2.2)
# Requirement already satisfied: pywin32-ctypes!=0.1.0,!=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from keyring>=18.0.1->flytekit) (0.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->flytekit) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=14.0->docker<7.0.0,>=5.0.3->flytekit) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\lib\site-packages (from python-slugify>=4.0.0->cookiecutter>=1.7.3->flytekit) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.4->flytekit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.4->flytekit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.4->flytekit) (3.3)
# Collecting types-toml
#   Downloading types_toml-0.10.8.1-py3-none-any.whl (4.5 kB)
# Requirement already satisfied: toml in c:\programdata\anaconda3\lib\site-packages (from responses>=0.10.7->flytekit) (0.10.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.4.0->dataclasses-json>=0.5.2->flytekit) (0.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from gitpython->flytekit) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\tinul piumika\appdata\roaming\python\python39\site-packages (from gitdb<5,>=4.0.1->gitpython->flytekit) (5.0.0)
# Requirement already satisfied: cryptography>=3.3 in c:\programdata\anaconda3\lib\site-packages (from pyopenssl->flytekit) (3.4.8)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=3.3->pyopenssl->flytekit) (1.15.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3->pyopenssl->flytekit) (2.21)
# Building wheels for collected packages: docker-image-py
#   Building wheel for docker-image-py (setup.py): started
#   Building wheel for docker-image-py (setup.py): finished with status 'done'
#   Created wheel for docker-image-py: filename=docker_image_py-0.1.12-py3-none-any.whl size=8836 sha256=bf78e3f22de17d4161530b34d32978876a6bdfc10d04eb38954cdd5d9853510a
#   Stored in directory: c:\users\tinul piumika\appdata\local\pip\cache\wheels\32\35\e8\11eecb60c93baea12949e2257f87301a4365c48291d612632b
# Successfully built docker-image-py
# Installing collected packages: urllib3, protobuf, typing-inspect, types-toml, pywin32, protoc-gen-swagger, grpcio, googleapis-common-protos, statsd, retry, responses, pytimeparse, python-json-logger, pyarrow, natsort, marshmallow-jsonschema, grpcio-status, flyteidl, docstring-parser, docker-image-py, docker, diskcache, dataclasses-json, cloudpickle, flytekit
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.1.1
#     Uninstalling cloudpickle-1.1.1:
#       Successfully uninstalled cloudpickle-1.1.1
# Successfully installed cloudpickle-2.2.1 dataclasses-json-0.5.7 diskcache-5.4.0 docker-6.0.1 docker-image-py-0.1.12 docstring-parser-0.15 flyteidl-1.3.4 flytekit-1.3.1 googleapis-common-protos-1.58.0 grpcio-1.51.1 grpcio-status-1.51.1 marshmallow-jsonschema-0.13.0 natsort-8.2.0 protobuf-4.21.12 protoc-gen-swagger-0.1.0 pyarrow-10.0.1 python-json-logger-2.0.4 pytimeparse-1.1.8 pywin32-305 responses-0.22.0 retry-0.9.2 statsd-3.3.0 types-toml-0.10.8.1 typing-inspect-0.8.0 urllib3-1.26.14
#   WARNING: The script plasma_store.exe is installed in 'C:\Users\Tinul Piumika\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script natsort.exe is installed in 'C:\Users\Tinul Piumika\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts flyte-cli.exe, pyflyte-execute.exe, pyflyte-fast-execute.exe, pyflyte-map-execute.exe and pyflyte.exe are installed in 'C:\Users\Tinul Piumika\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.12 which is incompatible.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.12 which is incompatible.
# kfp 0.1.40 requires cloudpickle==1.1.1, but you have cloudpickle 2.2.1 which is incompatible.
# kfp 0.1.40 requires urllib3<1.25,>=1.15, but you have urllib3 1.26.14 which is incompatible.

# %%
import typing
import pandas as pd
import numpy as np

from flytekit import task, workflow

@task
def generate_normal_df(n:int, mean: float, sigma: float) -> pd.DataFrame:
    return pd.DataFrame({"numbers": np.random.normal(mean, sigma,size=n)})

@task
def compute_stats(df: pd.DataFrame) -> typing.Tuple[float, float]:
    return float(df["numbers"].mean()), float(df["numbers"].std())

@workflow
def wf(n: int = 200, mean: float = 0.0, sigma: float = 1.0) -> typing.Tuple[float, float]:
    return compute_stats(df=generate_normal_df(n=n, mean=mean, sigma=sigma))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       2 import pandas as pd
#       3 import numpy as np
# ----> 5 from flytekit import task, workflow
#       7 @task
#       8 def generate_normal_df(n:int, mean: float, sigma: float) -> pd.DataFrame:
#       9     return pd.DataFrame({"numbers": np.random.normal(mean, sigma,size=n)})
#
# File ~\AppData\Roaming\Python\Python39\site-packages\flytekit\__init__.py:165, in <module>
#     162 else:
#     163     from importlib.metadata import entry_points
# --> 165 from flytekit.core.base_sql_task import SQLTask
#     166 from flytekit.core.base_task import SecurityContext, TaskMetadata, kwtypes
#     167 from flytekit.core.checkpointer import Checkpoint
#
# File ~\AppData\Roaming\Python\Python39\site-packages\flytekit\core\base_sql_task.py:4, in <module>
#       1 import re
#       2 from typing import Any, Dict, Optional, Type, TypeVar
# ----> 4 from flytekit.core.base_task import PythonTask, TaskMetadata
#       5 from flytekit.core.interface import Interface
#       7 T = TypeVar("T")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\flytekit\core\base_task.py:41, in <module>
#      39 from flytekit.core.tracker import TrackedInstance
#      40 from flytekit.core.type_engine import TypeEngine
# ---> 41 from flytekit.deck.deck import Deck
#      42 from flytekit.loggers import logger
#      43 from flytekit.models import dynamic_job as _dynamic_job
#
# File ~\AppData\Roaming\Python\Python39\site-packages\flytekit\deck\__init__.py:17, in <module>
#       1 """
#       2 ==========
#       3 Flyte Deck
#    (...)
#      14    TopFrameRenderer
#      15 """
# ---> 17 from .deck import Deck
#      18 from .renderer import TopFrameRenderer
#
# File ~\AppData\Roaming\Python\Python39\site-packages\flytekit\deck\deck.py:5, in <module>
#       2 import typing
#       3 from typing import Optional
# ----> 5 from jinja2 import Environment, FileSystemLoader, select_autoescape
#       7 from flytekit.core.context_manager import ExecutionParameters, ExecutionState, FlyteContext, FlyteContextManager
#       8 from flytekit.loggers import logger
#
# File ~\AppData\Roaming\Python\Python39\site-packages\jinja2\__init__.py:12, in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# File ~\AppData\Roaming\Python\Python39\site-packages\jinja2\environment.py:25, in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# File ~\AppData\Roaming\Python\Python39\site-packages\jinja2\defaults.py:3, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# File ~\AppData\Roaming\Python\Python39\site-packages\jinja2\filters.py:13, in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      15 from ._compat import abc
#      16 from ._compat import imap
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (C:\Users\Tinul Piumika\AppData\Roaming\Python\Python39\site-packages\markupsafe\__init__.py)
